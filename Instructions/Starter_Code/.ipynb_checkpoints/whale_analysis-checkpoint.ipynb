# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
# set the file path
file_path = Path("Resources/whale_returns.csv")

# create a Pandas dataframe from a csv file 
whale_returns_df = pd.read_csv(file_path, index_col = 0, parse_dates = [0] , infer_datetime_format = True)

# amke sure the information is in the same order for all 3 sets of data
whale_returns_df = whale_returns_df.sort_index()
whale_returns_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# ...

# %%
# Count nulls
whale_returns_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns_df = whale_returns_df.dropna().copy()
whale_returns_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
# set the file path
file_path = Path("Resources/algo_returns.csv")

# create a Pandas dataframe from a csv file
algo_returns_df = pd.read_csv(file_path, index_col = 0, parse_dates = [0], infer_datetime_format = True)
algo_returns_df = algo_returns_df.sort_index()
algo_returns_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1241 rows x 2 columns]

# %%
# Count nulls
algo_returns_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns_df = algo_returns_df.dropna()
algo_returns_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
# set the file path
file_path = Path("Resources/sp500_history.csv")

# create a Pandas dataframe from a csv file
sp500_history_df = pd.read_csv(file_path, index_col = 0, parse_dates = [0], infer_datetime_format = True)
sp500_history_df = sp500_history_df.sort_index()
sp500_history_df
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93
# ...              ...
# 2019-04-16  $2907.06
# 2019-04-17  $2900.45
# 2019-04-18  $2905.03
# 2019-04-22  $2907.97
# 2019-04-23  $2933.68
#
# [1649 rows x 1 columns]

# %%
# Check Data Types
sp500_history_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1649 entries, 2012-10-01 to 2019-04-23
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1649 non-null   object
# dtypes: object(1)
# memory usage: 25.8+ KB

# %%
# Fix Data Types
sp500_history_df = pd.read_csv(file_path, index_col = 0, parse_dates=True, infer_datetime_format=True)
sp500_history_df = sp500_history_df.sort_index().copy()

# Fix $ and , in data and convert from string to floating numeric in Close
sp500_history_df["Close"] = sp500_history_df["Close"].replace(r'[$,]','',regex=True).astype("float")
sp500_history_df
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93
# ...             ...
# 2019-04-16  2907.06
# 2019-04-17  2900.45
# 2019-04-18  2905.03
# 2019-04-22  2907.97
# 2019-04-23  2933.68
#
# [1649 rows x 1 columns]

# %%
# Calculate Daily Returns
sp500_daily_returns = sp500_history_df.pct_change().dropna()
sp500_daily_returns
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %%
# Drop nulls
sp500_daily_returns = sp500_daily_returns.dropna()
sp500_daily_returns
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_daily_returns.rename(columns = {'Close':'SP500'}, inplace = True)

sp500_daily_returns
# Out:
#                SP500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.

combined_df = pd.concat([whale_returns_df,  algo_returns_df, sp500_daily_returns], axis="columns", join="inner")
combined_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
daily_returns = combined_df

daily_returns.plot(figsize = (40,20), title =" Daily")
# Out:
# <AxesSubplot:title={'center':' Daily'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + daily_returns).cumprod()
# -1
# Plot cumulative returns
cumulative_returns.plot(figsize = (40,20), title =" Cumulative Returns")
# Out:
# <AxesSubplot:title={'center':' Cumulative Returns'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk

daily_returns.plot.box(figsize = (20,10), title =" Daily Box Plot")

# cumulative_returns.plot.box(figsize = (20,20), title =" Daily Box Plot")
# Out:
# <AxesSubplot:title={'center':' Daily Box Plot'}>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios

combined_std = combined_df.std()
combined_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# SP500                          0.008554
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500


# Determine which portfolios are riskier than the S&P 500

sp500_std = combined_std["SP500"]

combined_std >sp500_std
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# SP500                          False
# dtype: bool

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualised_std = combined_std * np.sqrt(252)
annualised_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# SP500                          0.135786
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
rolling_std_21 = combined_df.rolling(window=21).std()

# Plot the rolling standard deviation
rolling_std_21.plot(figsize = (20,10), title =" 21 Day Standard Deviation")
# Out:
# <AxesSubplot:title={'center':' 21 Day Standard Deviation'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = daily_returns.corr()
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# SP500                                         0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %%
# Display de correlation matrix
sns.heatmap(correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
covariance_algo1 = daily_returns['Algo 1'].cov(sp500_daily_returns["SP500"])
covariance_algo1
# Out:
# 1.821774999163274e-05

# %%
# Calculate variance of S&P 500
variance_sp500 = sp500_daily_returns["SP500"].var()
variance_sp500
# Out:
# 6.579270583158746e-05

# %%
# Computing beta
beta = covariance_algo1 / variance_sp500
beta
# Out:
# 0.2768961963392345

# %%
# Plot beta trend
# Set the figure and plot the different datasets as multiple trends on the same figure

covariance_algo1_rolling = daily_returns['Algo 1'].rolling(window=30).cov(sp500_daily_returns["SP500"])
beta_plot = covariance_algo1_rolling / variance_sp500
beta_plot.plot(figsize=(20, 10), title='Beta Trend Algo1 and SP500')
# Out:
# <AxesSubplot:title={'center':'Beta Trend Algo1 and SP500'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
combined_df.ewm(halflife=21).std().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (combined_df.mean() * 252) / (combined_df.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# SP500                          0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot( kind = "bar", title='Beta Trend Algo1 and SP500')
# Out:
# <AxesSubplot:title={'center':'Beta Trend Algo1 and SP500'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P 500 index.
#
# * `GOOG` - [Google, LLC](https://en.wikipedia.org/wiki/Google)
#
# * `AAPL` - [Apple Inc.](https://en.wikipedia.org/wiki/Apple_Inc.)
#
# * `COST` - [Costco Wholesale Corporation](https://en.wikipedia.org/wiki/Costco)

# %%
# Reading data from 1st stock
appl_path = Path('Resources/aapl_historical.csv')
appl_df = pd.read_csv(appl_path, index_col='Trade DATE',  parse_dates= [0], infer_datetime_format=True, usecols=['Trade DATE','NOCP'])
appl_df.head()
# Out:
#               NOCP
# Trade DATE
# 2019-05-09  200.72
# 2019-05-08  202.90
# 2019-05-07  202.86
# 2019-05-06  208.48
# 2019-05-03  211.75

# %%
# Reading data from 2nd stock

cost_path = Path('Resources/cost_historical.csv')
cost_df = pd.read_csv(cost_path, index_col='Trade DATE', parse_dates= [0], infer_datetime_format=True, usecols=['Trade DATE','NOCP'])
cost_df.head()
# Out:
#               NOCP
# Trade DATE
# 2019-05-09  243.47
# 2019-05-08  241.34
# 2019-05-07  240.18
# 2019-05-06  244.23
# 2019-05-03  244.62

# %%
# Reading data from 3rd stock
goog_path = Path('Resources/goog_historical.csv')
goog_df = pd.read_csv(goog_path, index_col='Trade DATE', parse_dates= [0], infer_datetime_format=True, usecols=['Trade DATE','NOCP'])
goog_df.head()
# Out:
#                NOCP
# Trade DATE
# 2019-05-09  1162.38
# 2019-05-08  1166.27
# 2019-05-07  1174.10
# 2019-05-06  1189.39
# 2019-05-03  1185.40

# %%
# Combine all stocks in a single DataFrame
new_portfolio = pd.concat([appl_df, cost_df, goog_df], axis='columns', join='inner')

new_portfolio
# Out:
#               NOCP    NOCP     NOCP
# Trade DATE
# 2019-05-09  200.72  243.47  1162.38
# 2019-05-08  202.90  241.34  1166.27
# 2019-05-07  202.86  240.18  1174.10
# 2019-05-06  208.48  244.23  1189.39
# 2019-05-03  211.75  244.62  1185.40
# ...            ...     ...      ...
# 2018-05-17  186.99  199.60  1078.59
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-11  188.59  195.76  1098.26
#
# [250 rows x 3 columns]

# %%
# Reset Date index
new_portfolio = new_portfolio.sort_index()

# %%
# Reorganize portfolio data by having a column per symbol
new_portfolio.columns = ['APPL', 'COST', 'GOOG']
new_portfolio
# Out:
#               APPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59
# ...            ...     ...      ...
# 2019-05-03  211.75  244.62  1185.40
# 2019-05-06  208.48  244.23  1189.39
# 2019-05-07  202.86  240.18  1174.10
# 2019-05-08  202.90  241.34  1166.27
# 2019-05-09  200.72  243.47  1162.38
#
# [250 rows x 3 columns]

# %%
# Calculate daily returns
new_portfolio_daily_return = new_portfolio.pct_change()

# Drop NAs
new_portfolio_daily_return = new_portfolio_daily_return.dropna()


new_portfolio.columns = ['APPL', 'COST', 'GOOG']
new_portfolio_daily_return.head()
# Out:
#                 APPL      COST      GOOG
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940
# 2018-05-18 -0.003637 -0.003206 -0.011339

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
portfolio_return = daily_return.mul(weights, axis=1).sum(axis=1)

# Display sample data
portfolio_return
# Out:
# Trade DATE
# 2019-05-08    0.001820
# 2019-05-07    0.000570
# 2019-05-06    0.019196
# 2019-05-03    0.004642
# 2019-05-02   -0.013131
#                 ...
# 2018-05-17    0.006112
# 2018-05-16    0.001618
# 2018-05-15   -0.009283
# 2018-05-14    0.010216
# 2018-05-11   -0.000012
# Length: 249, dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame

all_portfolio_return = pd.concat([new_portfolio_daily_return, portfolio_return ], axis='columns', join='inner')
all_portfolio_return

all_portfolio_return.columns = ['APPL', 'COST', 'GOOG',"Weighted"]
all_portfolio_return
# Out:
#                 APPL      COST      GOOG  Weighted
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766  0.010216
# 2018-05-15 -0.009088 -0.002042 -0.019060 -0.009283
# 2018-05-16  0.009333  0.016523  0.002354  0.001618
# 2018-05-17 -0.006324  0.004479 -0.002940  0.006112
# 2018-05-18 -0.003637 -0.003206 -0.011339 -0.007529
# ...              ...       ...       ...       ...
# 2019-05-02 -0.006508  0.004553 -0.004683 -0.013131
# 2019-05-03  0.012431  0.007953  0.019602  0.004642
# 2019-05-06 -0.015443 -0.001594  0.003366  0.019196
# 2019-05-07 -0.026957 -0.016583 -0.012855  0.000570
# 2019-05-08  0.000197  0.004830 -0.006669  0.001820
#
# [248 rows x 4 columns]

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
all_portfolio_returns = all_portfolio_return.dropna()
all_portfolio_returns.columns = ['APPL', 'COST', 'GOOG',"Weighted"]
all_portfolio_returns
# Out:
#                 APPL      COST      GOOG  Weighted
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766  0.010216
# 2018-05-15 -0.009088 -0.002042 -0.019060 -0.009283
# 2018-05-16  0.009333  0.016523  0.002354  0.001618
# 2018-05-17 -0.006324  0.004479 -0.002940  0.006112
# 2018-05-18 -0.003637 -0.003206 -0.011339 -0.007529
# ...              ...       ...       ...       ...
# 2019-05-02 -0.006508  0.004553 -0.004683 -0.013131
# 2019-05-03  0.012431  0.007953  0.019602  0.004642
# 2019-05-06 -0.015443 -0.001594  0.003366  0.019196
# 2019-05-07 -0.026957 -0.016583 -0.012855  0.000570
# 2019-05-08  0.000197  0.004830 -0.006669  0.001820
#
# [248 rows x 4 columns]

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
annualized_std = all_portfolio_returns * np.sqrt(252)
annualized_std
# Out:
#                 APPL      COST      GOOG  Weighted
# Trade DATE
# 2018-05-14 -0.037037  0.009731  0.028041  0.162177
# 2018-05-15 -0.144275 -0.032417 -0.302571 -0.147365
# 2018-05-16  0.148153  0.262301  0.037361  0.025682
# 2018-05-17 -0.100386  0.071100 -0.046665  0.097022
# 2018-05-18 -0.057729 -0.050900 -0.179999 -0.119519
# ...              ...       ...       ...       ...
# 2019-05-02 -0.103306  0.072279 -0.074339 -0.208453
# 2019-05-03  0.197340  0.126243  0.311179  0.073696
# 2019-05-06 -0.245146 -0.025309  0.053433  0.304732
# 2019-05-07 -0.427929 -0.263243 -0.204072  0.009049
# 2019-05-08  0.003130  0.076669 -0.105866  0.028886
#
# [248 rows x 4 columns]

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
all_portfolio_returns.rolling(window=21).std()

# Plot rolling standard deviation
all_portfolio_returns.plot(figsize=(20, 10), title='Rolling 21-Day Standard Deviation')
# Out:
# <AxesSubplot:title={'center':'Rolling 21-Day Standard Deviation'}, xlabel='Trade DATE'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation

correlation =all_portfolio_returns.corr()
correlation
# Out:
#               APPL      COST      GOOG  Weighted
# APPL      1.000000  0.415586  0.655007  0.099286
# COST      0.415586  1.000000  0.385999 -0.018413
# GOOG      0.655007  0.385999  1.000000  0.023062
# Weighted  0.099286 -0.018413  0.023062  1.000000

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta

rolling_covariance = all_portfolio_returns['Weighted'].rolling(window=60).cov(sp500_daily_returns['SP500'])
rolling_variance = sp500_daily_returns['SP500'].rolling(window=60).var()
rolling_beta1 = rolling_covariance / rolling_variance
rolling_beta1.plot(figsize=(20, 10), title='Portfolio - Weighted')
# Out:
# <AxesSubplot:title={'center':'Portfolio - Weighted'}>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios

sharpe_ratios = (all_portfolio_returns.mean() * 252) / (all_portfolio_returns.std() * np.sqrt(252))
sharpe_ratios
# Out:
# APPL        0.399009
# COST        1.120859
# GOOG        0.363228
# Weighted   -0.376848
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind='bar', title='Annualised Sharpe Ratio')
# Out:
# <AxesSubplot:title={'center':'Annualised Sharpe Ratio'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
print(f" Overall my portfolio has done well with all three stocks (APPL, COST, GOOG) performing above average.")
# Out:
#  Overall my portfolio has done well with all three stocks (APPL, COST, GOOG) performing above average.
